# %% [markdown]
# # 파이썬 벼락 치기 노트
#
# 안녕하세요, 이 노트는 파이썬이나 일반적인 프로그래밍을 포괄적으로 다루지는 않습니다. 수업에 필수적으로 필요하다고 생각되는 파이썬만을 다루고 있습니다. 프로그래밍 경험을 더 쌓으시려면 다른 Open course 강의나 서적을 참고하여 공부해주시기 바랍니다.
#
#
# 먼저 노트의 구성은 다음과 같습니다.
#
# 1. 파이썬 기초 문법에 대해 알아봅니다.
#
# 2. 조건문과 루프들에 대해 알아봅니다.
#
# 3. 간단한 함수 만드는법과 다양한 파이썬 내장 함수

# %% [markdown]
# ## 파이썬 기초 문법
#
# - 프린트하는법,리스트,사전,숫자형,문자형,불린형(참/거짓)등 파이썬 기초 문법에 대해 알아봅니다.

# %% [markdown]
# ### 파이썬 기본 사칙 연산, 몫/나머지 구하는법

# %%
print(10 + 1) # 답 : 11
# Out:
# 11

# %%
print(10 -1) # 답 : 9
# Out:
# 9

# %%
print(10 * 3 )# 답 : 30
# Out:
# 30

# %%
print(10 / 2) # 답 : 5
# Out:
# 5.0

# %%
print(10 ** 3) # 10의 제곱 답 : 100
# Out:
# 1000

# %%
print(10 // 3) # 10을 2로 나누었을시의 몫
# Out:
# 3

# %%
print(10 % 2) # 10을 2로 나누었을시의 나머지
# Out:
# 0

# %%
print(10 % 3) # 10을 3로 나누었을시의 나머지
# Out:
# 1

# %%
print((1 + 2) * (2 + 4) + 11 ) # 파이썬은 기본 사칙연산 순서를 잘 따른다.
# Out:
# 29

# %% [markdown]
# ### 부울린(boolean)

# %%
Alpha = 0

# %%
true = 'a'

# %%
False, True
# Out:
# (False, True)

# %%
int(False), int(True)
# Out:
# (0, 1)

# %%
True = 'a'
# Out:
#   File "/tmp/ipykernel_220/3545788840.py", line 1
#     True = 'a'
#     ^
# SyntaxError: cannot assign to True

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
1 in [1,2,3]
# Out:
# True

# %%
4 in [1,2,3]
# Out:
# False

# %% [markdown]
# ### 비교 연산자

# %%
1 < 2
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
1 != 1
# Out:
# False

# %%
1 == 2
# Out:
# False

# %%
1 >= 1
# Out:
# True

# %%
'나' == '너'
# Out:
# False

# %%
name= '이름'

# %%
name2 = name

# %%
name2
# Out:
# '이름'

# %%
'이름' == name
# Out:
# True

# %%
list_a = [1,2,3]

# %%
list_b = list_a

# %%
list_b.append(4)

# %%
list_a
# Out:
# [1, 2, 3, 4]

# %%
list_a is list_b
# Out:
# True

# %%
list_a is [1,2,3,4]
# Out:
# False

# %%
'이름' is name
# Out:
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# /tmp/ipykernel_220/906275315.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   '이름' is name
# False

# %%
name2 is name
# Out:
# True

# %%
(1>2) and (3>2) # and 앞뒤로 둘 다 true 여야만 true
# Out:
# False

# %%
(1<2) and (3>2)
# Out:
# True

# %%
(1>2) or (3>2) # 둘중하나 이상만 true 면 true
# Out:
# True

# %%
(1==2) or (3<2) # 둘다 false 여야만 false
# Out:
# False

# %%
x=3

# %%
(1<=x) and (x<=4)
# Out:
# True

# %%
1<= x<= 4
# Out:
# True

# %% [markdown]
# ### 변수 할당
#
# - 파이썬에서는 '=' 을 통해 변수를 할당할 수 있는데 이때 변수로 할당하려는 문자의 첫 글자는 숫자여서는 안되고 이미 파이썬에 내장된 예약어(for , and while ...)등도 사용할 수 없다..

# %%
and = 3
# Out:
#   File "/tmp/ipykernel_220/967448499.py", line 1
#     and = 3
#     ^
# SyntaxError: invalid syntax

# %%
1x = 10
# Out:
#   File "/tmp/ipykernel_220/3431583271.py", line 1
#     1x = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
x1= 10

# %%
x = 10
y = 20
x+y
# Out:
# 30

# %%
z = x + y
z
# Out:
# 30

# %%
1x=10 # 숫자로 정했을 시 에러
# Out:
#   File "<ipython-input-33-6a99a6762c34>", line 1
#     1x=10 # 숫자로 정했을 시 에러
#      ^
# SyntaxError: invalid syntax

# %%
True = 10
# Out:
#   File "<ipython-input-61-398a5163d1af>", line 1
#     True = 10
#     ^
# SyntaxError: cannot assign to True

# %%
and = 10 # 예약어로 정했을 시 에러
# Out:
#   File "<ipython-input-62-aa309b72df18>", line 1
#     and = 10 # 예약어로 정했을 시 에러
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 문자열
#
# - '' , "" 을 사용하여 문자열을 만들 수 있다. 이때 문자열 안에 '',"" 을 사용할시에는 \를 추가해준다.

# %%
print('안녕하세요')
# Out:
# 안녕하세요

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %%
print("'사용법1'",'"사용법1"')
# Out:
# '사용법1' "사용법1"

# %%
print('\'사용법2\'', "\"사용법2\"")
# Out:
# '사용법2' "사용법2"

# %%
a = "이렇게.format을 쓰면 {}안에 넣어준다!"

# %%
print(
    'format 사용법: {}.'.format(
        "이렇게.format을 쓰면 {}안에 넣어준다!"
    )
)
# Out:
# format 사용법: 이렇게.format을 쓰면 {}안에 넣어준다!.

# %%
print(
    'format 사용법: {}.'.format(
        a
    )
)
# Out:
# format 사용법: 이렇게.format을 쓰면 {}안에 넣어준다!.

# %%
print('format 사용법2: {} {}'.format("이렇게.format을 쓰면", " 순서대로{}안에 넣어준다"))
# Out:
# format 사용법2: 이렇게.format을 쓰면  순서대로{}안에 넣어준다

# %%
print('format 사용법3 변수 이용: {b} {a} {a}'.format(b ="이렇게.format을 쓰면", a=" 변수에 맞게 {}안에 넣어준다"))
# Out:
# format 사용법3 변수 이용: 이렇게.format을 쓰면  변수에 맞게 {}안에 넣어준다  변수에 맞게 {}안에 넣어준다

# %%
a
# Out:
# '이렇게.format을 쓰면 {}안에 넣어준다!'

# %%
print(f"format 사용법3 변수 이용: {a}")
# Out:
# format 사용법3 변수 이용: 이렇게.format을 쓰면 {}안에 넣어준다!

# %%
string = 'A B C ,abc'
string.split()
# Out:
# ['A', 'B', 'C', ',abc']

# %%
string.split(',')
# Out:
# ['A B C ', 'abc']

# %%
string.lower()#영어를 쓸경우 다음과 같은 함수를 사용할 수 있음을 알아두자.
# Out:
# 'a b c ,abc'

# %%
string.upper()
# Out:
# 'A B C ,ABC'

# %%
string.title()
# Out:
# 'A B C ,Abc'

# %%
string = ' \n\n A B C ,abc      \n\n'
print(string)
# Out:
#
#
#  A B C ,abc

# %%
string.strip()
# Out:
# 'A B C ,abc'

# %%
string.lstrip()
# Out:
# 'A B C ,abc      \n\n'

# %%
'apple banana'.title()
# Out:
# 'Apple Banana'

# %% [markdown]
# ### 파이썬 리스트
# - 리스트 안에는 숫자,문자열,리스트 등 다양한것들을 넣을 수 있다.

# %%
first_list = ['내','이름','은']

# %%
first_list
# Out:
# ['내', '이름', '은']

# %%
first_list.append('비밀') # list 마지막에 추가해 줄 때는 append를 이용한다.

# %%
first_list
# Out:
# ['내', '이름', '은', '비밀']

# %%
first_list.extend(first_list)

# %%
first_list
# Out:
# ['내', '이름', '은', '비밀', '내', '이름', '은', '비밀']

# %%
first_list[0]
# Out:
# '내'

# %%
first_list[1]
# Out:
# '이름'

# %%
first_list[1:3]
# Out:
# ['이름', '은']

# %%
first_list[0].strip()
# Out:
# '내'

# %%
first_list[0]
# Out:
# '내'

# %%
first_list[0:1]
# Out:
# ['내']

# %%
first_list[0:1].strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_220/1439541922.py in <cell line: 0>()
# ----> 1 first_list[0:1].strip()
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
first_list[0] = '너'

# %%
first_list
# Out:
# ['너', '이름', '은', '비밀', '내', '이름', '은', '비밀']

# %%
first_list.pop()
# Out:
# '비밀'

# %%
first_list
# Out:
# ['너', '이름', '은', '비밀', '내', '이름']

# %%
a = first_list.pop() # 리스트 맨 뒤 요소를 제거함

# %%
a
# Out:
# '은'

# %%
first_list
# Out:
# ['너', '이름', '은', '비밀', '내', '이름']

# %%
list_in_list = [1,2,3,[4,5,['list']]]

# %%
list_in_list[3]
# Out:
# [4, 5, ['list']]

# %%
list_in_list[3][2]
# Out:
# ['list']

# %%
list_in_list[3][2][0]
# Out:
# 'list'

# %% [markdown]
# ### 사전

# %%
first_dictionary = {'키1':'value1','키2':'value2'}

# %%
first_dictionary
# Out:
# {'키1': 'value1', '키2': 'value2'}

# %%
first_dictionary['키1']
# Out:
# 'value1'

# %%
first_dictionary.keys()
# Out:
# dict_keys(['키1', '키2'])

# %%
list(first_dictionary.keys())
# Out:
# ['키1', '키2']

# %%
first_dictionary.values()
# Out:
# dict_values(['value1', 'value2'])

# %%
first_dictionary.items()
# Out:
# dict_items([('키1', 'value1'), ('키2', 'value2')])

# %%
for key, value in first_dictionary.items():
    print(key, value)
# Out:
# 키1 value1
# 키2 value2

# %%
for key, _ in first_dictionary:
    print(key, _)
# Out:
# 키 1
# 키 2

# %% [markdown]
# ### 튜플

# %%
first_tuple = (1,2,3)

# %%
first_tuple
# Out:
# (1, 2, 3)

# %%
first_tuple[0]
# Out:
# 1

# %%
first_tuple[0] = '튜플은 추가가 안된다'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_220/2047304685.py in <cell line: 0>()
# ----> 1 first_tuple[0] = '튜플은 추가가 안된다'
#
# TypeError: 'tuple' object does not support item assignment

# %%
first_tuple = [1,2,3]

# %% [markdown]
# ### 세트

# %%
{'a','b','c','d'}
# Out:
# {'a', 'b', 'c', 'd'}

# %%
{'a','b','c','d','a','b','a','b','c','d','d','d','d','d','d'}
# Out:
# {'a', 'b', 'c', 'd'}

# %%
{"a", "b", "c"}.intersection({"b","d"})
# Out:
# {'b'}

# %% [markdown]
# ## 조건문과 루프들
# - if, elif, else등의 조건문 사용법을 알아보고, for while 등의 루프 사용법에 대해 알아봅니다.

# %% [markdown]
# ## if 조건문 사용법

# %%
if 1 < 10:
    print('1 < 10 입니다')
# Out:
# 1 < 10 입니다

# %%
if 1 < 2:
    print('1<2입니다.')
else:
    print('1<2 가 아닙니다.')
# Out:
# 1<2입니다.

# %%
if 1 > 2:
    print('1>2입니다.')
else:
    print('1>2 가 아닙니다.')
# Out:
# 1>2 가 아닙니다.

# %%
if 1 == 2:
    print('1 은 2입니다')
elif 3 != 3:
    print('3은 3입니다.')
else:
    print('둘다 틀렸습니다')
# Out:
# 둘다 틀렸습니다

# %% [markdown]
# ## 반복문 루프

# %%
range(0,5) # 0부터 4까지 숫자 뽑아줍니다.
# Out:
# range(0, 5)

# %%
list(range(0,5))
# Out:
# [0, 1, 2, 3, 4]

# %%
for i in [0, 1, 2, 3, 4]: # for 루프는 설정한 조건 만큼 돌아갑니다.
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2,7): # for 루프는 설정한 조건 만큼 돌아갑니다.
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
x = range(0,5)
[i*2 for i in x] #리스트 안에 for 문
# Out:
# [0, 2, 4, 6, 8]

# %%
[i*2 for i in range(0,5)]
# Out:
# [0, 2, 4, 6, 8]

# %%
i = 0
while i < 5: # 조건이 성립되는한 계속 돌아갑니다.
    print(i)
    i = i+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## 파이썬 함수 만들기
# - def, lambda 를 이용해서 함수를 만드는 방법을 알아보자.

# %%
def first_function(x):
    print(x)

    # return None

# %%
first_function(2)
# Out:
# 2

# %%
first_function()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_220/1799474648.py in <cell line: 0>()
# ----> 1 first_function()
#
# TypeError: first_function() missing 1 required positional argument: 'x'

# %%
def first_function(x=1):
    print(x)

# %%
a = first_function()
# Out:
# 1

# %%
a

# %%
a is None
# Out:
# True

# %%
def first_function_return(x=1):
    # print(x)
    return x

# %%
a = first_function_return()
a
# Out:
# 1

# %%
first_function
# Out:
# <function __main__.first_function(x=1)>

# %%
first_function()
# Out:
# 1

# %%
first_function("안녕하세요")
# Out:
# 안녕하세요

# %%
first_function(1+2)
# Out:
# 3

# %%
def add(x,y):
    return x+y

# %%
add1 = add(2,3)

# %%
print(add1)
# Out:
# 5

# %% [markdown]
# ## lambda expressions

# %%
abcd = lambda x: x*2
abcd
# Out:
# <function __main__.<lambda>(x)>

# %%
abcd(3)
# Out:
# 6

# %%
lambda x: x*2
# Out:
# <function __main__.<lambda>(x)>
